# %% [markdown]
# <a href="https://colab.research.google.com/github/Nyeonging/Camera_Pose_M/blob/main/deeplearning_team5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 라이브러리

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torchvision import transforms
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from torchsummary import summary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import random

# %% [markdown]
# # Data

# %%
# 파일 경로 설정
csv_file_path = "C:/JES/RC/rc0610.csv" # 경로 맞게 수정 필요
image_folder = "C:/JES/RC/vid/Frames0605/" # 경로 맞게 수정 필요

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)                # CSV 파일을 DataFrame으로 읽기
df.iloc[:, 4:7] = np.deg2rad(df.iloc[:, 4:7])  # 각도를 라디안으로 변환

# 데이터프레임의 첫 몇 줄을 출력하여 확인하기
df.head()
# Out:
#               name          x         y         z   heading     pitch  \
# 0  frame002788.png -22.267843  6.201859  3.634597  2.685670  1.435295
# 1  frame002789.png -22.348587  6.183848  3.636773  2.570259  1.431567
# 2  frame002790.png -22.327660  6.096769  3.633957  2.514414  1.433386
# 3  frame002791.png -22.314033  6.069438  3.633712  2.452865  1.435694
# 4  frame005092.png   4.918484  8.298428  3.871030  3.003135  1.501904
#
#        roll
# 0 -0.016853
# 1 -0.028845
# 2  0.004247
# 3  0.025942
# 4 -0.348559

# %%
import matplotlib.pyplot as plt
import cv2
import os

# 랜덤으로 하나의 이미지와 그에 해당하는 라벨을 선택하여 출력하기
random_index = random.randint(0, len(df) - 1)
print('Imagename:' ,df.iloc[random_index,0])
print(df.iloc[random_index,1:])

#시각화
image_name = df.iloc[random_index,0]
image_path = os.path.join(image_folder, image_name)

print("Image Path:", image_path)
print("File Exists:", os.path.exists(image_path))

image = cv2.imread(image_path)
if image is None:
    print("Error: Could not read the image. Please check the file path and file name.")
else:
    try:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        plt.imshow(image)
        plt.title('Example Image')
        plt.axis('off')
        plt.show()
    except Exception as e:
        print(f"An error occurred while processing the image: {e}")
# Out:
# Imagename: frame004311.png
# x            0.0765
# y          11.73177
# z          3.782248
# heading    0.969548
# pitch      1.501567
# roll       0.452528
# Name: 1194, dtype: object
# Image Path: C:/JES/RC/vid/Frames0605/frame004311.png
# File Exists: True

# %% [markdown]
# ## 데이터 분할

# %%
from sklearn.model_selection import train_test_split

# 데이터프레임의 컬럼명을 지정
df.columns = ['image', 'x', 'y', 'z', 'heading', 'pitch', 'roll'] # 이미지, 위치 및 포즈 정보 컬럼명

# 필요한 데이터를 float 타입으로 변환
df[['x', 'y', 'z', 'heading', 'pitch', 'roll']] = df[['x', 'y', 'z', 'heading', 'pitch', 'roll']].astype(float) # 수치 데이터로 다루기 위해 float 타입으로 변환

# 전체 데이터를 학습(0.8), 테스트 세트로 분할(0.2)
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42) # 테스트 세트 20%
# 학습 세트를 다시 학습 세트와 검증 세트로 분할
train_data, val_data = train_test_split(train_data, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

print(f'Train set size: {len(train_data)}') # train(학습) : 60%
print(f'Validation set size: {len(val_data)}') # validation(검증) : 20%
print(f'Test set size: {len(test_data)}') # test : 20%
# Out:
# Train set size: 2064
# Validation set size: 688
# Test set size: 689

# %% [markdown]
# ## 데이터 전처리

# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch

# PoseDataset 클래스 정의: 이미지와 라벨 로드, 전처리하는 역할
class PoseDataset(Dataset):
    def __init__(self, dataframe, image_folder, transform=None):
        self.dataframe = dataframe
        self.image_folder = image_folder
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_folder, self.dataframe.iloc[idx, 0]) # 이미지 파일 전체 경로
        image = Image.open(img_name).convert('RGB') # 이미지 열어서 RGB 로 변환
        labels = self.dataframe.iloc[idx, 1:].values.astype('float32') # 라벨 읽어와서 float32로
        labels = torch.tensor(labels, dtype=torch.float32) # 라벨 값을 Pytorch 텐서로
        if self.transform:
            image = self.transform(image) # 이미지 전처리
        return image, labels

# Data augmentation 및 변환 설정하기: 훈련 데이터에 적용할 변환 정의
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),                                                 # 이미지 크기 256x256 으로 -> 모델 입력 차원 통일
    transforms.RandomHorizontalFlip(),                                             # 이미지를 랜덤으로 수평 반전 -> 일반화 성능 향상시켜줌
    transforms.RandomRotation(10),                                                 # 이미지를 랜덤으로 10도 회전 -> 다양한 각도에서 이미지 인식할 수 있도록
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2), # 이미지 컬러 조정
    transforms.ToTensor(),                                                         # 이미지를 PyTorch 텐서로 변환
])

# Transform for validation and test datasets : 데이터 전처리 정의
test_transform = transforms.Compose([
    transforms.Resize((256, 256)), # 이미지 크기를 256x256
    transforms.ToTensor(),
])

# 데이터셋 및 데이터 로더
train_dataset = PoseDataset(dataframe=train_data, image_folder=image_folder, transform=train_transform) # 훈련 데이터셋 생성
val_dataset = PoseDataset(dataframe=val_data, image_folder=image_folder, transform=test_transform) # 검증 데이터셋 생성
test_dataset = PoseDataset(dataframe=test_data, image_folder=image_folder, transform=test_transform) # 테스트 데이터셋 생성

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

#장치 설정해줌 (GPU 가능시 GPU 로)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # 모델

# %% [markdown]
# ## loss function & architecture

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
import matplotlib.pyplot as plt
import random
import math

# Custom Loss Function 정의
class CustomMinLoss(nn.Module):
    def __init__(self):
        super(CustomMinLoss, self).__init__()

    def forward(self, output, target):
        diff = (output - target)  # 예측값과 실제값의 차이 계산
        diff = torch.where(diff > torch.tensor(math.pi), diff - 2 * math.pi, diff)  # 0과 pi 사이의 차이 계산, 차이가 π보다 큰 경우, 2π를 빼준다
        diff = torch.where(diff < -torch.tensor(math.pi), diff + 2 * math.pi, diff)  # -pi와 0 사이의 차이 계산, 차이가 -π보다 작은 경우, 2π를 더한다
        diff = torch.abs(diff)  # 차이를 절댓값으로 변환
        return torch.mean(diff)  # 차이를 평균 계산하여 반환

# Mixed Loss Function 정의 (MSE + CustomMinLoss 가중 합)
class MixedLoss(nn.Module):
    def __init__(self, alpha=0.5, beta=0.5):
        super(MixedLoss, self).__init__()
        self.mse_loss = nn.MSELoss()
        self.custom_min_loss = CustomMinLoss()
        self.alpha = alpha # MSE loss 가중치
        self.beta = beta # CustomMinLoss 가중치

    def forward(self, output, target):
        mse_loss_value = self.mse_loss(output, target) # MSE 계산
        custom_min_loss_value = self.custom_min_loss(output, target) # CustomMinLoss 계산
        return self.alpha * mse_loss_value + self.beta * custom_min_loss_value # 두 loss 가중 합쳐서 반환

# ResNet50 기반으로 한 CameraPoseEstimationModel 정의
class CameraPoseEstimationModel(nn.Module):
    def __init__(self):
        super(CameraPoseEstimationModel, self).__init__()
        self.backbone = models.resnet50(pretrained=True)              # 사전 학습된 ResNet50 모델
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, 6) # fc layer 를 6개의 output 뉴런으로

    def forward(self, x):
        x = self.backbone(x)                                          # 입력 데이터를 ResNet50 모델을 통해서 전달
        pos = x[:, :3]                                                # First 3 values for (x, y, z) 위치로 사용
        orient = x[:, 3:]                                             # Last 3 values for (yaw, pitch, roll) 포즈로 사용
        return pos, orient                                            # 위치와 포즈를 반환

# AdamW 라는 옵티마이저 로 weigth decay 적절히 적용
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CameraPoseEstimationModel().to(device)
mixed_loss = MixedLoss(alpha=0.7, beta=0.3) # MixedLoss loss
optimizer = optim.AdamW(model.parameters(), lr=0.001) # AdamW optimizer, learning rate 설정
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#학습률 감소 스케줄러(ReduceLROnPklateau) 추가 : 성능 향상이 없으면 학습률 줄여줌
# Out:
# c:\Users\seoze\anaconda3\envs\spike\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\seoze\anaconda3\envs\spike\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ## Performances

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

train_losses = [] # 훈련 손실 값 저장 리스트
val_losses = [] # 검증 손실 값 저장 리스트

num_epochs = 100 # 에포크 설정
for epoch in range(num_epochs):
    model.train() # 학습 모드
    train_loss = 0.0 # 훈련 손실 값 초기화
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device) # GPU로 데이터 이동
        optimizer.zero_grad() # 옵티마이저 기울기 초기화
        pos, orient = model(images) # 모델을 통해 위치와 포즈 예측
        loss = mixed_loss(torch.cat((pos, orient), dim=1), labels) # 손실 계산
        loss.backward() # 역전파
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) # 기울기 폭주 방지
        optimizer.step() # 옵티마이저로 가중치 업데이트
        train_loss += loss.item() * images.size(0) # 배치 손실 값 누적

    train_loss /= len(train_loader.dataset) # 훈련 손실 평균 계산
    train_losses.append(train_loss) # 훈련 손실 리스트에 추가
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}')

    model.eval() # 평가 모드
    val_loss = 0.0 # 검증 손실 값 초기화
    with torch.no_grad(): # 평가 중에는 기울기 계산 안함
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            pos, orient = model(images)
            loss = mixed_loss(torch.cat((pos, orient), dim=1), labels)
            val_loss += loss.item() * images.size(0)

    val_loss /= len(val_loader.dataset)
    val_losses.append(val_loss)
    print(f'Epoch {epoch+1}/{num_epochs}, Validation Loss: {val_loss:.4f}')

    # Step the scheduler
    scheduler.step(val_loss)
# Out:
# Epoch 1/100, Train Loss: 14.5233
# Epoch 1/100, Validation Loss: 29.0206
# Epoch 2/100, Train Loss: 7.7278
# Epoch 2/100, Validation Loss: 8.5975
# Epoch 3/100, Train Loss: 6.0150
# Epoch 3/100, Validation Loss: 13.9402
# Epoch 4/100, Train Loss: 6.0257
# Epoch 4/100, Validation Loss: 7.6598
# Epoch 5/100, Train Loss: 4.8872
# Epoch 5/100, Validation Loss: 3.9746
# Epoch 6/100, Train Loss: 3.6334
# Epoch 6/100, Validation Loss: 11.1735
# Epoch 7/100, Train Loss: 3.3255
# Epoch 7/100, Validation Loss: 3.7542
# Epoch 8/100, Train Loss: 3.0205
# Epoch 8/100, Validation Loss: 2.5147
# Epoch 9/100, Train Loss: 2.9363
# Epoch 9/100, Validation Loss: 1.6449
# Epoch 10/100, Train Loss: 2.9053
# Epoch 10/100, Validation Loss: 1.6704
# Epoch 11/100, Train Loss: 2.3985
# Epoch 11/100, Validation Loss: 5.7005
# Epoch 12/100, Train Loss: 2.5581
# Epoch 12/100, Validation Loss: 3.3206
# Epoch 13/100, Train Loss: 2.5341
# Epoch 13/100, Validation Loss: 2.5371
# Epoch 14/100, Train Loss: 1.9518
# Epoch 14/100, Validation Loss: 1.0248
# Epoch 15/100, Train Loss: 1.6851
# Epoch 15/100, Validation Loss: 1.0329
# Epoch 16/100, Train Loss: 1.4616
# Epoch 16/100, Validation Loss: 1.0408
# Epoch 17/100, Train Loss: 1.4015
# Epoch 17/100, Validation Loss: 0.7839
# Epoch 18/100, Train Loss: 1.3717
# Epoch 18/100, Validation Loss: 0.8179
# Epoch 19/100, Train Loss: 1.1521
# Epoch 19/100, Validation Loss: 0.8410
# Epoch 20/100, Train Loss: 1.3637
# Epoch 20/100, Validation Loss: 0.8638
# Epoch 21/100, Train Loss: 1.1339
# Epoch 21/100, Validation Loss: 1.3803
# Epoch 22/100, Train Loss: 1.0775
# Epoch 22/100, Validation Loss: 0.5541
# Epoch 23/100, Train Loss: 0.8216
# Epoch 23/100, Validation Loss: 0.6293
# Epoch 24/100, Train Loss: 0.7497
# Epoch 24/100, Validation Loss: 0.7743
# Epoch 25/100, Train Loss: 0.7507
# Epoch 25/100, Validation Loss: 0.5129
# Epoch 26/100, Train Loss: 0.6822
# Epoch 26/100, Validation Loss: 0.4955
# Epoch 27/100, Train Loss: 0.7011
# Epoch 27/100, Validation Loss: 0.5648
# Epoch 28/100, Train Loss: 0.5863
# Epoch 28/100, Validation Loss: 0.5726
# Epoch 29/100, Train Loss: 0.6320
# Epoch 29/100, Validation Loss: 0.4669
# Epoch 30/100, Train Loss: 0.5989
# Epoch 30/100, Validation Loss: 0.4836
# Epoch 31/100, Train Loss: 0.5640
# Epoch 31/100, Validation Loss: 0.4426
# Epoch 32/100, Train Loss: 0.5632
# Epoch 32/100, Validation Loss: 0.5716
# Epoch 33/100, Train Loss: 0.4800
# Epoch 33/100, Validation Loss: 0.4624
# Epoch 34/100, Train Loss: 0.5479
# Epoch 34/100, Validation Loss: 0.4938
# Epoch 35/100, Train Loss: 0.5129
# Epoch 35/100, Validation Loss: 0.4343
# Epoch 36/100, Train Loss: 0.4736
# Epoch 36/100, Validation Loss: 0.4417
# Epoch 37/100, Train Loss: 0.4389
# Epoch 37/100, Validation Loss: 0.4262
# Epoch 38/100, Train Loss: 0.4943
# Epoch 38/100, Validation Loss: 0.3976
# Epoch 39/100, Train Loss: 0.4379
# Epoch 39/100, Validation Loss: 0.4328
# Epoch 40/100, Train Loss: 0.4129
# Epoch 40/100, Validation Loss: 0.3946
# Epoch 41/100, Train Loss: 0.4330
# Epoch 41/100, Validation Loss: 0.8329
# Epoch 42/100, Train Loss: 0.3945
# Epoch 42/100, Validation Loss: 0.4620
# Epoch 43/100, Train Loss: 0.3971
# Epoch 43/100, Validation Loss: 0.4557
# Epoch 44/100, Train Loss: 0.3561
# Epoch 44/100, Validation Loss: 0.4462
# Epoch 45/100, Train Loss: 0.3015
# Epoch 45/100, Validation Loss: 0.3787
# Epoch 46/100, Train Loss: 0.2768
# Epoch 46/100, Validation Loss: 0.3197
# Epoch 47/100, Train Loss: 0.2617
# Epoch 47/100, Validation Loss: 0.3323
# Epoch 48/100, Train Loss: 0.2672
# Epoch 48/100, Validation Loss: 0.3511
# Epoch 49/100, Train Loss: 0.2422
# Epoch 49/100, Validation Loss: 0.2869
# Epoch 50/100, Train Loss: 0.2397
# Epoch 50/100, Validation Loss: 0.3454
# Epoch 51/100, Train Loss: 0.2835
# Epoch 51/100, Validation Loss: 0.3405
# Epoch 52/100, Train Loss: 0.2355
# Epoch 52/100, Validation Loss: 0.3043
# Epoch 53/100, Train Loss: 0.2696
# Epoch 53/100, Validation Loss: 0.3868
# Epoch 54/100, Train Loss: 0.2606
# Epoch 54/100, Validation Loss: 0.2575
# Epoch 55/100, Train Loss: 0.2118
# Epoch 55/100, Validation Loss: 0.2599
# Epoch 56/100, Train Loss: 0.2168
# Epoch 56/100, Validation Loss: 0.2641
# Epoch 57/100, Train Loss: 0.2000
# Epoch 57/100, Validation Loss: 0.2563
# Epoch 58/100, Train Loss: 0.1943
# Epoch 58/100, Validation Loss: 0.2565
# Epoch 59/100, Train Loss: 0.1914
# Epoch 59/100, Validation Loss: 0.2669
# Epoch 60/100, Train Loss: 0.1890
# Epoch 60/100, Validation Loss: 0.2546
# Epoch 61/100, Train Loss: 0.1878
# Epoch 61/100, Validation Loss: 0.2504
# Epoch 62/100, Train Loss: 0.1843
# Epoch 62/100, Validation Loss: 0.3017
# Epoch 63/100, Train Loss: 0.1841
# Epoch 63/100, Validation Loss: 0.2741
# Epoch 64/100, Train Loss: 0.1885
# Epoch 64/100, Validation Loss: 0.2373
# Epoch 65/100, Train Loss: 0.1710
# Epoch 65/100, Validation Loss: 0.2560
# Epoch 66/100, Train Loss: 0.1796
# Epoch 66/100, Validation Loss: 0.2503
# Epoch 67/100, Train Loss: 0.2014
# Epoch 67/100, Validation Loss: 0.2517
# Epoch 68/100, Train Loss: 0.1814
# Epoch 68/100, Validation Loss: 0.2303
# Epoch 69/100, Train Loss: 0.1920
# Epoch 69/100, Validation Loss: 0.2581
# Epoch 70/100, Train Loss: 0.1591
# Epoch 70/100, Validation Loss: 0.2437
# Epoch 71/100, Train Loss: 0.1656
# Epoch 71/100, Validation Loss: 0.2409
# Epoch 72/100, Train Loss: 0.1655
# Epoch 72/100, Validation Loss: 0.2388
# Epoch 73/100, Train Loss: 0.1616
# Epoch 73/100, Validation Loss: 0.2427
# Epoch 74/100, Train Loss: 0.1559
# Epoch 74/100, Validation Loss: 0.2377
# Epoch 75/100, Train Loss: 0.1477
# Epoch 75/100, Validation Loss: 0.2408
# Epoch 76/100, Train Loss: 0.1577
# Epoch 76/100, Validation Loss: 0.2518
# Epoch 77/100, Train Loss: 0.1415
# Epoch 77/100, Validation Loss: 0.2286
# Epoch 78/100, Train Loss: 0.1422
# Epoch 78/100, Validation Loss: 0.2185
# Epoch 79/100, Train Loss: 0.1350
# Epoch 79/100, Validation Loss: 0.2395
# Epoch 80/100, Train Loss: 0.1410
# Epoch 80/100, Validation Loss: 0.2304
# Epoch 81/100, Train Loss: 0.1410
# Epoch 81/100, Validation Loss: 0.2457
# Epoch 82/100, Train Loss: 0.1491
# Epoch 82/100, Validation Loss: 0.2313
# Epoch 83/100, Train Loss: 0.1481
# Epoch 83/100, Validation Loss: 0.2738
# Epoch 84/100, Train Loss: 0.1378
# Epoch 84/100, Validation Loss: 0.2220
# Epoch 85/100, Train Loss: 0.1336
# Epoch 85/100, Validation Loss: 0.2248
# Epoch 86/100, Train Loss: 0.1398
# Epoch 86/100, Validation Loss: 0.2207
# Epoch 87/100, Train Loss: 0.1690
# Epoch 87/100, Validation Loss: 0.2363
# Epoch 88/100, Train Loss: 0.1399
# Epoch 88/100, Validation Loss: 0.2246
# Epoch 89/100, Train Loss: 0.1336
# Epoch 89/100, Validation Loss: 0.2256
# Epoch 90/100, Train Loss: 0.1301
# Epoch 90/100, Validation Loss: 0.2217
# Epoch 91/100, Train Loss: 0.1336
# Epoch 91/100, Validation Loss: 0.2219
# Epoch 92/100, Train Loss: 0.1411
# Epoch 92/100, Validation Loss: 0.2317
# Epoch 93/100, Train Loss: 0.1537
# Epoch 93/100, Validation Loss: 0.2174
# Epoch 94/100, Train Loss: 0.1755
# Epoch 94/100, Validation Loss: 0.2634
# Epoch 95/100, Train Loss: 0.1226
# Epoch 95/100, Validation Loss: 0.2206
# Epoch 96/100, Train Loss: 0.1310
# Epoch 96/100, Validation Loss: 0.2437
# Epoch 97/100, Train Loss: 0.1229
# Epoch 97/100, Validation Loss: 0.2155
# Epoch 98/100, Train Loss: 0.1323
# Epoch 98/100, Validation Loss: 0.2448
# Epoch 99/100, Train Loss: 0.1326
# Epoch 99/100, Validation Loss: 0.2267
# Epoch 100/100, Train Loss: 0.1276
# Epoch 100/100, Validation Loss: 0.2458

# %%
# 손실 변화 시각화
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
# 샘플 이미지와 예측 결과 시각화
indices = random.sample(range(len(test_dataset)), 10) # 테스트 데이터셋에서 랜덤으로 10개 샘플 선택
sample_images, sample_labels = zip(*[test_dataset[i] for i in indices]) # 샘플 이미지와 라벨 묶기
sample_images = torch.stack(sample_images).to(device)
sample_labels = torch.stack(sample_labels).to(device)

with torch.no_grad(): # 평가 중에는 기울기 계산 x
    sample_outputs = model(sample_images) # 모델을 통해 위치와 포즈 예측

for i in range(10):
    sample_image = sample_images[i].cpu().permute(1, 2, 0).numpy() # 이미지를 numpy 배열로 변환
    sample_label = sample_labels[i].cpu().numpy() # 라벨을 numpy 배열로 변환
    sample_output = torch.cat(sample_outputs, dim=1)[i].cpu().numpy() # 위치와 자세를 하나의 텐서로 결합하고 numpy 배열로 변환

    plt.figure()
    plt.imshow(sample_image)
    plt.title(f'Sample Image {i}')
    plt.axis('off')
    plt.show()

    print(f'Actual Label: {sample_label}')
    print(f'Predicted Label: {sample_output}')
# Out:
# Actual Label: [ 2.2665064 -1.6845363  4.176314   2.4606547  1.4063331 -0.3126856]
# Predicted Label: [ 1.9060179  -2.241873    4.049454    2.507636    1.381631   -0.19682802]
# Actual Label: [-0.41229904 53.07316     3.2055397   2.317304    1.4946957  -0.1389257 ]
# Predicted Label: [-0.70314634 51.596054    3.154221    2.3784366   1.4715387  -0.17731763]
# Actual Label: [ 3.7432995  28.438492    3.700916   -0.45627305  1.5367731  -0.4784694 ]
# Predicted Label: [ 3.7081645 27.870619   3.6557803 -0.5545503  1.5183432 -0.5712398]
# Actual Label: [-18.971542     6.1163225    3.9446654   -2.343877     1.270785
#    0.03522263]
# Predicted Label: [-18.973866     5.7214956    3.9055996   -2.656319     1.3028418
#   -0.17981161]
# Actual Label: [ 6.621508    3.3530538   3.781104   -2.2572386   1.5197729  -0.37939736]
# Predicted Label: [ 6.7584963   3.48016     3.6887686  -1.6413126   1.5059634  -0.16818504]
# Actual Label: [ 3.3608818   8.950533    4.0525947  -2.5343714   1.4202838  -0.22889507]
# Predicted Label: [ 3.4031322   8.777026    3.9120696  -2.6241152   1.4013094  -0.00912004]
# Actual Label: [-0.34785116 22.071995    4.377554    0.9217602   1.4586712   0.29465345]
# Predicted Label: [-0.33210424 21.671274    4.3475413   1.0242349   1.4672095   0.33285496]
# Actual Label: [ 1.0410792  13.78278     3.6493542   2.9822524   1.522299   -0.01619221]
# Predicted Label: [ 1.0910177  13.385567    3.6153681   1.3318934   1.5008785   0.09560955]
# Actual Label: [ 3.195735   -2.182009    4.4161754   1.5454348   1.4371929  -0.34826016]
# Predicted Label: [ 2.9258597  -2.0411494   4.318585    1.9033784   1.3945827  -0.18108882]
# Actual Label: [ 3.1697764 -1.767489   4.3565702  1.5178589  1.362338  -0.3924905]
# Predicted Label: [ 2.9946516  -1.6144147   4.3307824   1.6477178   1.39245    -0.33985013]

# %%
import torch
import random
import pandas as pd
import matplotlib.pyplot as plt

# 랜덤으로 50개 샘플 선택
indices = random.sample(range(len(test_dataset)), 50)
sample_images, sample_labels = zip(*[test_dataset[i] for i in indices])
sample_images = torch.stack(sample_images).to(device)
sample_labels = torch.stack(sample_labels).to(device)

with torch.no_grad():
    sample_outputs = model(sample_images)

# 결과 저장을 위한 리스트 초기화
actual_labels = []
predicted_labels = []

for i in range(50):
    sample_label = sample_labels[i].cpu().numpy()
    sample_output = torch.cat(sample_outputs, dim=1)[i].cpu().numpy()

    # 실제 라벨과 예측 라벨을 리스트에 추가
    actual_labels.append(sample_label)
    predicted_labels.append(sample_output)

# DataFrame 생성
df_actual = pd.DataFrame(actual_labels, columns=['x', 'y', 'z', 'heading', 'pitch', 'roll'])
df_predicted = pd.DataFrame(predicted_labels, columns=['x', 'y', 'z', 'heading', 'pitch', 'roll'])

# CSV 파일로 저장
df_actual.to_csv('actual_labels.csv', index=False)
df_predicted.to_csv('predicted_labels.csv', index=False)

print("CSV 파일이 성공적으로 생성되었습니다.")
# Out:
# CSV 파일이 성공적으로 생성되었습니다.

# %%
import torch

# Assuming `model` is your model instance
torch.save(model,'model0619.pth')

# %% [markdown]
# # 결과 시각화

# %% [markdown]
# ## Accuracy

# %%
import numpy as np

# 정확도 계산 함수
def calculate_accuracy_with_threshold(model, data_loader, device, position_threshold, angle_threshold):
    model.eval()  # 모델을 평가 모드로 전환
    total = 0  # 전체 샘플 수
    correct = 0  # 정확히 예측한 샘플 수

    with torch.no_grad():  # 평가 시에는 기울기 계산 안 함
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)
            pos, orient = model(images) # 모델을 통해 위치와 각도 예측

            # 위치 오차 계산
            position_error = torch.norm(pos - labels[:, :3], dim=1)  # 예측 위치와 실제 위치의 차이(유클리드 거리) 계산

            # 각도 오차 계산
            angle_error = torch.norm(orient - labels[:, 3:], dim=1)  # 예측 각도와 실제 각도의 차이 계산

            # 정확도 계산
            correct += ((position_error < position_threshold) & (angle_error < np.deg2rad(angle_threshold))).sum().item()  # 위치 오차와 각도 오차가 임계값 이내인 샘플 수를 카운트
            total += labels.size(0)  # 전체 샘플 수 갱신

    accuracy = 100 * correct / total  # 정확도 계산 (백분율)
    return accuracy  # 정확도 반환

# %% [markdown]
# ### position accuracy

# %%
# 다양한 임계값에 따른 정확도 계산
position_thresholds = np.arange(0.0, 3.1, 0.1)  # 0.5m 간격으로 0.5m ~ 10m 까지
angle_threshold = 360 # 각도 오차 임계값은 20도로 고정

accuracies = []

for pos_threshold in position_thresholds:
    accuracy = calculate_accuracy_with_threshold(model, test_loader, device, pos_threshold, angle_threshold)  # 임계값에 따른 정확도 계산
    accuracies.append(accuracy)
    print(f'Position Threshold: {pos_threshold:.2f}, Accuracy: {accuracy:.2f}%')

# 정확도 시각화
plt.figure(figsize=(10, 5))
plt.plot(position_thresholds, accuracies, marker='o', label=f'Angle Threshold: {angle_threshold}°')
plt.xlabel('Position Threshold')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Position Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Position Threshold: 0.00, Accuracy: 0.00%
# Position Threshold: 0.10, Accuracy: 2.32%
# Position Threshold: 0.20, Accuracy: 12.19%
# Position Threshold: 0.30, Accuracy: 28.74%
# Position Threshold: 0.40, Accuracy: 44.27%
# Position Threshold: 0.50, Accuracy: 57.62%
# Position Threshold: 0.60, Accuracy: 65.75%
# Position Threshold: 0.70, Accuracy: 72.86%
# Position Threshold: 0.80, Accuracy: 78.96%
# Position Threshold: 0.90, Accuracy: 84.62%
# Position Threshold: 1.00, Accuracy: 88.53%
# Position Threshold: 1.10, Accuracy: 90.86%
# Position Threshold: 1.20, Accuracy: 93.18%
# Position Threshold: 1.30, Accuracy: 94.92%
# Position Threshold: 1.40, Accuracy: 96.37%
# Position Threshold: 1.50, Accuracy: 97.53%
# Position Threshold: 1.60, Accuracy: 98.26%
# Position Threshold: 1.70, Accuracy: 98.84%
# Position Threshold: 1.80, Accuracy: 98.98%
# Position Threshold: 1.90, Accuracy: 98.98%
# Position Threshold: 2.00, Accuracy: 99.13%
# Position Threshold: 2.10, Accuracy: 99.13%
# Position Threshold: 2.20, Accuracy: 99.27%
# Position Threshold: 2.30, Accuracy: 99.42%
# Position Threshold: 2.40, Accuracy: 99.42%
# Position Threshold: 2.50, Accuracy: 99.42%
# Position Threshold: 2.60, Accuracy: 99.42%
# Position Threshold: 2.70, Accuracy: 99.42%
# Position Threshold: 2.80, Accuracy: 99.56%
# Position Threshold: 2.90, Accuracy: 99.56%
# Position Threshold: 3.00, Accuracy: 99.56%

# %% [markdown]
# ###angle accuracy

# %%
angle_thresholds_rad = np.linspace(0, 90, 91)  # 0부터 π/2 라디안 (90도)까지 1도 간격으로
position_threshold = 10  # 위치 임계값은 1m로 고정

accuracies_a = []

for angle_threshold in angle_thresholds_rad:
    accuracy = calculate_accuracy_with_threshold(model, test_loader, device, position_threshold, angle_threshold)
    accuracies_a.append(accuracy)
    print(f'Angle Threshold: {angle_threshold}°, Accuracy: {accuracy:.6f}%')

# 정확도 시각화
plt.figure(figsize=(10, 5))
plt.plot(angle_thresholds_rad, accuracies_a, marker='o', label=f'Position Threshold: {position_threshold}m')
plt.xlabel('Angle Threshold (°)')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Angle Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Angle Threshold: 0.0°, Accuracy: 0.000000%
# Angle Threshold: 1.0°, Accuracy: 0.435414%
# Angle Threshold: 2.0°, Accuracy: 2.612482%
# Angle Threshold: 3.0°, Accuracy: 5.660377%
# Angle Threshold: 4.0°, Accuracy: 11.901306%
# Angle Threshold: 5.0°, Accuracy: 19.593614%
# Angle Threshold: 6.0°, Accuracy: 25.834543%
# Angle Threshold: 7.0°, Accuracy: 32.220610%
# Angle Threshold: 8.0°, Accuracy: 38.171263%
# Angle Threshold: 9.0°, Accuracy: 44.847605%
# Angle Threshold: 10.0°, Accuracy: 50.217707%
# Angle Threshold: 11.0°, Accuracy: 56.748911%
# Angle Threshold: 12.0°, Accuracy: 61.103048%
# Angle Threshold: 13.0°, Accuracy: 63.860668%
# Angle Threshold: 14.0°, Accuracy: 67.198839%
# Angle Threshold: 15.0°, Accuracy: 69.956459%
# Angle Threshold: 16.0°, Accuracy: 72.423803%
# Angle Threshold: 17.0°, Accuracy: 75.181422%
# Angle Threshold: 18.0°, Accuracy: 77.503628%
# Angle Threshold: 19.0°, Accuracy: 79.825835%
# Angle Threshold: 20.0°, Accuracy: 80.986938%
# Angle Threshold: 21.0°, Accuracy: 82.148041%
# Angle Threshold: 22.0°, Accuracy: 83.164006%
# Angle Threshold: 23.0°, Accuracy: 84.034833%
# Angle Threshold: 24.0°, Accuracy: 85.631350%
# Angle Threshold: 25.0°, Accuracy: 86.502177%
# Angle Threshold: 26.0°, Accuracy: 87.373004%
# Angle Threshold: 27.0°, Accuracy: 88.243832%
# Angle Threshold: 28.0°, Accuracy: 88.824383%
# Angle Threshold: 29.0°, Accuracy: 89.404935%
# Angle Threshold: 30.0°, Accuracy: 90.420900%
# Angle Threshold: 31.0°, Accuracy: 90.856313%
# Angle Threshold: 32.0°, Accuracy: 91.436865%
# Angle Threshold: 33.0°, Accuracy: 91.727141%
# Angle Threshold: 34.0°, Accuracy: 92.162554%
# Angle Threshold: 35.0°, Accuracy: 92.597968%
# Angle Threshold: 36.0°, Accuracy: 92.743106%
# Angle Threshold: 37.0°, Accuracy: 93.033382%
# Angle Threshold: 38.0°, Accuracy: 93.323657%
# Angle Threshold: 39.0°, Accuracy: 94.049347%
# Angle Threshold: 40.0°, Accuracy: 94.339623%
# Angle Threshold: 41.0°, Accuracy: 94.339623%
# Angle Threshold: 42.0°, Accuracy: 94.484761%
# Angle Threshold: 43.0°, Accuracy: 94.484761%
# Angle Threshold: 44.0°, Accuracy: 94.629898%
# Angle Threshold: 45.0°, Accuracy: 94.775036%
# Angle Threshold: 46.0°, Accuracy: 94.775036%
# Angle Threshold: 47.0°, Accuracy: 94.920174%
# Angle Threshold: 48.0°, Accuracy: 95.065312%
# Angle Threshold: 49.0°, Accuracy: 95.355588%
# Angle Threshold: 50.0°, Accuracy: 95.500726%
# Angle Threshold: 51.0°, Accuracy: 95.500726%
# Angle Threshold: 52.0°, Accuracy: 95.500726%
# Angle Threshold: 53.0°, Accuracy: 95.645864%
# Angle Threshold: 54.0°, Accuracy: 95.936139%
# Angle Threshold: 55.0°, Accuracy: 95.936139%
# Angle Threshold: 56.0°, Accuracy: 95.936139%
# Angle Threshold: 57.0°, Accuracy: 95.936139%
# Angle Threshold: 58.0°, Accuracy: 95.936139%
# Angle Threshold: 59.0°, Accuracy: 95.936139%
# Angle Threshold: 60.0°, Accuracy: 96.081277%
# Angle Threshold: 61.0°, Accuracy: 96.081277%
# Angle Threshold: 62.0°, Accuracy: 96.081277%
# Angle Threshold: 63.0°, Accuracy: 96.081277%
# Angle Threshold: 64.0°, Accuracy: 96.226415%
# Angle Threshold: 65.0°, Accuracy: 96.226415%
# Angle Threshold: 66.0°, Accuracy: 96.226415%
# Angle Threshold: 67.0°, Accuracy: 96.226415%
# Angle Threshold: 68.0°, Accuracy: 96.371553%
# Angle Threshold: 69.0°, Accuracy: 96.371553%
# Angle Threshold: 70.0°, Accuracy: 96.516691%
# Angle Threshold: 71.0°, Accuracy: 96.516691%
# Angle Threshold: 72.0°, Accuracy: 96.516691%
# Angle Threshold: 73.0°, Accuracy: 96.516691%
# Angle Threshold: 74.0°, Accuracy: 96.516691%
# Angle Threshold: 75.0°, Accuracy: 96.661829%
# Angle Threshold: 76.0°, Accuracy: 96.661829%
# Angle Threshold: 77.0°, Accuracy: 96.661829%
# Angle Threshold: 78.0°, Accuracy: 96.806967%
# Angle Threshold: 79.0°, Accuracy: 96.806967%
# Angle Threshold: 80.0°, Accuracy: 96.806967%
# Angle Threshold: 81.0°, Accuracy: 96.806967%
# Angle Threshold: 82.0°, Accuracy: 96.806967%
# Angle Threshold: 83.0°, Accuracy: 96.806967%
# Angle Threshold: 84.0°, Accuracy: 96.806967%
# Angle Threshold: 85.0°, Accuracy: 96.806967%
# Angle Threshold: 86.0°, Accuracy: 96.806967%
# Angle Threshold: 87.0°, Accuracy: 96.806967%
# Angle Threshold: 88.0°, Accuracy: 96.952104%
# Angle Threshold: 89.0°, Accuracy: 96.952104%
# Angle Threshold: 90.0°, Accuracy: 97.097242%

# %%
from torchsummary import summary

# 모델 요약 출력
model = CameraPoseEstimationModel().to(device)
summary(model, input_size=(3, 256, 256))
# Out:
# c:\Users\seoze\anaconda3\envs\spike\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\seoze\anaconda3\envs\spike\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           9,408
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#          MaxPool2d-4           [-1, 64, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]           4,096
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               ReLU-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#            Conv2d-11          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-12          [-1, 256, 64, 64]             512
#            Conv2d-13          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-14          [-1, 256, 64, 64]             512
#              ReLU-15          [-1, 256, 64, 64]               0
#        Bottleneck-16          [-1, 256, 64, 64]               0
#            Conv2d-17           [-1, 64, 64, 64]          16,384
#       BatchNorm2d-18           [-1, 64, 64, 64]             128
#              ReLU-19           [-1, 64, 64, 64]               0
#            Conv2d-20           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-21           [-1, 64, 64, 64]             128
#              ReLU-22           [-1, 64, 64, 64]               0
#            Conv2d-23          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-24          [-1, 256, 64, 64]             512
#              ReLU-25          [-1, 256, 64, 64]               0
#        Bottleneck-26          [-1, 256, 64, 64]               0
#            Conv2d-27           [-1, 64, 64, 64]          16,384
#       BatchNorm2d-28           [-1, 64, 64, 64]             128
#              ReLU-29           [-1, 64, 64, 64]               0
#            Conv2d-30           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-31           [-1, 64, 64, 64]             128
#              ReLU-32           [-1, 64, 64, 64]               0
#            Conv2d-33          [-1, 256, 64, 64]          16,384
#       BatchNorm2d-34          [-1, 256, 64, 64]             512
#              ReLU-35          [-1, 256, 64, 64]               0
#        Bottleneck-36          [-1, 256, 64, 64]               0
#            Conv2d-37          [-1, 128, 64, 64]          32,768
#       BatchNorm2d-38          [-1, 128, 64, 64]             256
#              ReLU-39          [-1, 128, 64, 64]               0
#            Conv2d-40          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-41          [-1, 128, 32, 32]             256
#              ReLU-42          [-1, 128, 32, 32]               0
#            Conv2d-43          [-1, 512, 32, 32]          65,536
#       BatchNorm2d-44          [-1, 512, 32, 32]           1,024
#            Conv2d-45          [-1, 512, 32, 32]         131,072
#       BatchNorm2d-46          [-1, 512, 32, 32]           1,024
#              ReLU-47          [-1, 512, 32, 32]               0
#        Bottleneck-48          [-1, 512, 32, 32]               0
#            Conv2d-49          [-1, 128, 32, 32]          65,536
#       BatchNorm2d-50          [-1, 128, 32, 32]             256
#              ReLU-51          [-1, 128, 32, 32]               0
#            Conv2d-52          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-53          [-1, 128, 32, 32]             256
#              ReLU-54          [-1, 128, 32, 32]               0
#            Conv2d-55          [-1, 512, 32, 32]          65,536
#       BatchNorm2d-56          [-1, 512, 32, 32]           1,024
#              ReLU-57          [-1, 512, 32, 32]               0
#        Bottleneck-58          [-1, 512, 32, 32]               0
#            Conv2d-59          [-1, 128, 32, 32]          65,536
#       BatchNorm2d-60          [-1, 128, 32, 32]             256
#              ReLU-61          [-1, 128, 32, 32]               0
#            Conv2d-62          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-63          [-1, 128, 32, 32]             256
#              ReLU-64          [-1, 128, 32, 32]               0
#            Conv2d-65          [-1, 512, 32, 32]          65,536
#       BatchNorm2d-66          [-1, 512, 32, 32]           1,024
#              ReLU-67          [-1, 512, 32, 32]               0
#        Bottleneck-68          [-1, 512, 32, 32]               0
#            Conv2d-69          [-1, 128, 32, 32]          65,536
#       BatchNorm2d-70          [-1, 128, 32, 32]             256
#              ReLU-71          [-1, 128, 32, 32]               0
#            Conv2d-72          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-73          [-1, 128, 32, 32]             256
#              ReLU-74          [-1, 128, 32, 32]               0
#            Conv2d-75          [-1, 512, 32, 32]          65,536
#       BatchNorm2d-76          [-1, 512, 32, 32]           1,024
#              ReLU-77          [-1, 512, 32, 32]               0
#        Bottleneck-78          [-1, 512, 32, 32]               0
#            Conv2d-79          [-1, 256, 32, 32]         131,072
#       BatchNorm2d-80          [-1, 256, 32, 32]             512
#              ReLU-81          [-1, 256, 32, 32]               0
#            Conv2d-82          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-83          [-1, 256, 16, 16]             512
#              ReLU-84          [-1, 256, 16, 16]               0
#            Conv2d-85         [-1, 1024, 16, 16]         262,144
#       BatchNorm2d-86         [-1, 1024, 16, 16]           2,048
#            Conv2d-87         [-1, 1024, 16, 16]         524,288
#       BatchNorm2d-88         [-1, 1024, 16, 16]           2,048
#              ReLU-89         [-1, 1024, 16, 16]               0
#        Bottleneck-90         [-1, 1024, 16, 16]               0
#            Conv2d-91          [-1, 256, 16, 16]         262,144
#       BatchNorm2d-92          [-1, 256, 16, 16]             512
#              ReLU-93          [-1, 256, 16, 16]               0
#            Conv2d-94          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-95          [-1, 256, 16, 16]             512
#              ReLU-96          [-1, 256, 16, 16]               0
#            Conv2d-97         [-1, 1024, 16, 16]         262,144
#       BatchNorm2d-98         [-1, 1024, 16, 16]           2,048
#              ReLU-99         [-1, 1024, 16, 16]               0
#       Bottleneck-100         [-1, 1024, 16, 16]               0
#           Conv2d-101          [-1, 256, 16, 16]         262,144
#      BatchNorm2d-102          [-1, 256, 16, 16]             512
#             ReLU-103          [-1, 256, 16, 16]               0
#           Conv2d-104          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-105          [-1, 256, 16, 16]             512
#             ReLU-106          [-1, 256, 16, 16]               0
#           Conv2d-107         [-1, 1024, 16, 16]         262,144
#      BatchNorm2d-108         [-1, 1024, 16, 16]           2,048
#             ReLU-109         [-1, 1024, 16, 16]               0
#       Bottleneck-110         [-1, 1024, 16, 16]               0
#           Conv2d-111          [-1, 256, 16, 16]         262,144
#      BatchNorm2d-112          [-1, 256, 16, 16]             512
#             ReLU-113          [-1, 256, 16, 16]               0
#           Conv2d-114          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-115          [-1, 256, 16, 16]             512
#             ReLU-116          [-1, 256, 16, 16]               0
#           Conv2d-117         [-1, 1024, 16, 16]         262,144
#      BatchNorm2d-118         [-1, 1024, 16, 16]           2,048
#             ReLU-119         [-1, 1024, 16, 16]               0
#       Bottleneck-120         [-1, 1024, 16, 16]               0
#           Conv2d-121          [-1, 256, 16, 16]         262,144
#      BatchNorm2d-122          [-1, 256, 16, 16]             512
#             ReLU-123          [-1, 256, 16, 16]               0
#           Conv2d-124          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-125          [-1, 256, 16, 16]             512
#             ReLU-126          [-1, 256, 16, 16]               0
#           Conv2d-127         [-1, 1024, 16, 16]         262,144
#      BatchNorm2d-128         [-1, 1024, 16, 16]           2,048
#             ReLU-129         [-1, 1024, 16, 16]               0
#       Bottleneck-130         [-1, 1024, 16, 16]               0
#           Conv2d-131          [-1, 256, 16, 16]         262,144
#      BatchNorm2d-132          [-1, 256, 16, 16]             512
#             ReLU-133          [-1, 256, 16, 16]               0
#           Conv2d-134          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-135          [-1, 256, 16, 16]             512
#             ReLU-136          [-1, 256, 16, 16]               0
#           Conv2d-137         [-1, 1024, 16, 16]         262,144
#      BatchNorm2d-138         [-1, 1024, 16, 16]           2,048
#             ReLU-139         [-1, 1024, 16, 16]               0
#       Bottleneck-140         [-1, 1024, 16, 16]               0
#           Conv2d-141          [-1, 512, 16, 16]         524,288
#      BatchNorm2d-142          [-1, 512, 16, 16]           1,024
#             ReLU-143          [-1, 512, 16, 16]               0
#           Conv2d-144            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-145            [-1, 512, 8, 8]           1,024
#             ReLU-146            [-1, 512, 8, 8]               0
#           Conv2d-147           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 8, 8]           4,096
#           Conv2d-149           [-1, 2048, 8, 8]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 8, 8]           4,096
#             ReLU-151           [-1, 2048, 8, 8]               0
#       Bottleneck-152           [-1, 2048, 8, 8]               0
#           Conv2d-153            [-1, 512, 8, 8]       1,048,576
#      BatchNorm2d-154            [-1, 512, 8, 8]           1,024
#             ReLU-155            [-1, 512, 8, 8]               0
#           Conv2d-156            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-157            [-1, 512, 8, 8]           1,024
#             ReLU-158            [-1, 512, 8, 8]               0
#           Conv2d-159           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 8, 8]           4,096
#             ReLU-161           [-1, 2048, 8, 8]               0
#       Bottleneck-162           [-1, 2048, 8, 8]               0
#           Conv2d-163            [-1, 512, 8, 8]       1,048,576
#      BatchNorm2d-164            [-1, 512, 8, 8]           1,024
#             ReLU-165            [-1, 512, 8, 8]               0
#           Conv2d-166            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-167            [-1, 512, 8, 8]           1,024
#             ReLU-168            [-1, 512, 8, 8]               0
#           Conv2d-169           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 8, 8]           4,096
#             ReLU-171           [-1, 2048, 8, 8]               0
#       Bottleneck-172           [-1, 2048, 8, 8]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                    [-1, 6]          12,294
#           ResNet-175                    [-1, 6]               0
# ================================================================
# Total params: 23,520,326
# Trainable params: 23,520,326
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 374.27
# Params size (MB): 89.72
# Estimated Total Size (MB): 464.74
# ----------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly


def eul2rot(heading, pitch, roll):
    """Converts Euler angles to rotation matrix: heading, pitch, roll -> rotation about X, Y, Z"""
   # heading, pitch, roll = np.deg2rad(heading), np.deg2rad(pitch), np.deg2rad(roll)

    # heading, pitch, roll 각도에 대한 회전 행렬 정의
    Rx = np.array([
        [1, 0, 0],
        [0, np.cos(heading), -np.sin(heading)],
        [0, np.sin(heading), np.cos(heading)]
    ])
    Ry = np.array([
        [np.cos(pitch), 0, np.sin(pitch)],
        [0, 1, 0],
        [-np.sin(pitch), 0, np.cos(pitch)]
    ])
    Rz = np.array([
        [np.cos(roll), -np.sin(roll), 0],
        [np.sin(roll), np.cos(roll), 0],
        [0, 0, 1]
    ])

    R = Rz @ Ry @ Rx  # 올바른 회전 순서 보장해줌
    return R

# 데이터 로드
data = pd.read_csv('C:/JES/jupyter/actual_labels.csv')  # 실제 라벨 데이터 로드
data2 = pd.read_csv('C:/JES/jupyter/predicted_labels.csv')  # 예측 라벨 데이터 로드

camScale = 1   # 카메라 크기 스케일링 변수

traceColor = 'magenta'  # 첫 번째 데이터셋의 경로 색상
camBodyColor = 'black'  # 첫 번째 데이터셋의 카메라 몸체 색상

traceColor2 = 'cyan'  # 두 번째 데이터셋의 경로 색상
camBodyColor2 = 'blue'  # 두 번째 데이터셋의 카메라 몸체 색상

fig = go.Figure()

rows = 240  # 카메라 행 크기
cols = 480  # 카메라 열 크기

# 카메라 중심 위치를 저장할 리스트
path_x = []  # 첫 번째 데이터셋의 경로 x 좌표
path_y = []  # 첫 번째 데이터셋의 경로 y 좌표
path_z = []  # 첫 번째 데이터셋의 경로 z 좌표

path_x2 = []  # 두 번째 데이터셋의 경로 x 좌표
path_y2 = []  # 두 번째 데이터셋의 경로 y 좌표
path_z2 = []  # 두 번째 데이터셋의 경로 z 좌표

# 카메라 몸체와 프레임을 figure에 추가해주는 함수
def add_camera_traces(data, trace_color, cam_body_color, path_x, path_y, path_z):
    for index, row in data.iterrows():
        R_gc = eul2rot(row['heading'], row['pitch'], row['roll'])   # 오일러 각도를 회전 행렬로 변환
        p_gc = np.array([row['x'], row['y'], row['z']])  # 카메라 위치 벡터

        path_x.append(p_gc[0])
        path_y.append(p_gc[1])
        path_z.append(p_gc[2])

        # 카메라 몸체와 프레임 정의
        camBody = np.zeros((3, 4))
        camBody[:, 0] = camScale * np.array([(rows/2), (rows-50), -(cols/2)]) / 1000
        camBody[:, 1] = camScale * np.array([-(rows/2), (rows-50), -(cols/2)]) / 1000
        camBody[:, 2] = camScale * np.array([-(rows/2), (rows-50), (cols/2)]) / 1000
        camBody[:, 3] = camScale * np.array([(rows/2), (rows-50), (cols/2)]) / 1000

        camFrame = camScale * ((rows/2) / 1000) * np.eye(3)

        # 카메라 몸체와 프레임을 회전 및 평행 이동
        camBody = R_gc.dot(camBody) + p_gc[:, np.newaxis]
        camFrame = R_gc.dot(camFrame) + p_gc[:, np.newaxis]

        # 카메라 몸체 그림
        for i in range(4):
            fig.add_trace(go.Scatter3d(
                x=[camBody[0, i], p_gc[0]],
                y=[camBody[1, i], p_gc[1]],
                z=[camBody[2, i], p_gc[2]],
                mode='lines',
                line=dict(color=cam_body_color, width=2)
            ))

        fig.add_trace(go.Scatter3d(
            x=camBody[0, [0, 1, 2, 3, 0]],
            y=camBody[1, [0, 1, 2, 3, 0]],
            z=camBody[2, [0, 1, 2, 3, 0]],
            mode='lines',
            line=dict(color=cam_body_color, width=2)
        ))

        # 카메라 프레임(RGB 축) 그림
        colors = ['red', 'green', 'blue']
        for i in range(3):
            fig.add_trace(go.Scatter3d(
                x=[camFrame[0, i], p_gc[0]],
                y=[camFrame[1, i], p_gc[1]],
                z=[camFrame[2, i], p_gc[2]],
                mode='lines',
                line=dict(color=colors[i], width=2)
            ))

# 첫 번째 데이터셋의 카메라 추가
add_camera_traces(data, traceColor, camBodyColor, path_x, path_y, path_z)

# 두 번째 데이터셋의 카메라 추가
add_camera_traces(data2, traceColor2, camBodyColor2, path_x2, path_y2, path_z2)

# 두 데이터셋의 카메라 경로 추가
fig.add_trace(go.Scatter3d(
    x=path_x,
    y=path_y,
    z=path_z,
    mode='lines',
    line=dict(color=traceColor, width=4),
    name='Camera Path Test'
))

fig.add_trace(go.Scatter3d(
    x=path_x2,
    y=path_y2,
    z=path_z2,
    mode='lines',
    line=dict(color=traceColor2, width=4),
    name='Camera Path Pred'
))

# 3D 시각화 레이아웃 업데이트
fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'   # 비율을 동일하게
    ),
    width=800,
    height=600
)

# 시각화 결과를 HTML 파일로 저장 및 자동 열기
plotly.offline.plot(fig, filename='camera_poses_comparison5.html', auto_open=True)
# Out:
# 'camera_poses_comparison5.html'
